# %% [markdown]
# # Superseded: use the unified notebook
#
# All **eval + plots** (and the same **clone/secret/setup** as training) are in [**`wildfire_train_eval_hf.ipynb`**](https://huggingface.co/spaces/Chunchunmaru-101/wildfire-env/blob/main/notebooks/wildfire_train_eval_hf.ipynb) (local: [`./wildfire_train_eval_hf.ipynb`](./wildfire_train_eval_hf.ipynb)).
#
# After `GITHUB_TOKEN` / `HF_TOKEN` and install steps: eval starts at **cell 5**; training (optional) is **cell 4**.
